# %% [markdown]
# <font color = "Blue">**You are a data scientist helping understand the data. By doing this challenge, you will learn data cleaning (data
# preparation), EDA and model building.**</font>
#
# Your analysis must be able to address the following requests:
# 1. Identify the missing values and replace them if necessary, and drop them
# 2. Find out the minimum, maximum and average Lot Area.
# 3. Plot the correlation between the columns
# 4. Plot the distribution of LotArea
# 5. Pair plot the following columns : 'LotFrontage','BsmtFinSF1','BsmtFinSF2','BsmtUnfSF‘,’SalePrice’
# 6. Run regression model based on above four columns and check the accuracy

# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("D:/COGNIXIA_Machine_Learning/Spyder/5. Machine_Learning/House_Price.csv")

# %%
data.columns
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
# ...

# %%
df = data[['LotFrontage','LotArea','BsmtFinSF1','BsmtFinSF2','BsmtUnfSF' , 'SalePrice']]

# %%
df.columns
# Out:
# Index(['LotFrontage', 'LotArea', 'BsmtFinSF1', 'BsmtFinSF2', 'BsmtUnfSF',
#        'SalePrice'],
#       dtype='object')

# %%
df
# Out:
#       LotFrontage  LotArea  BsmtFinSF1  BsmtFinSF2  BsmtUnfSF  SalePrice
# 0            65.0     8450         706           0        150     208500
# 1            80.0     9600         978           0        284     181500
# 2            68.0    11250         486           0        434     223500
# 3            60.0     9550         216           0        540     140000
# 4            84.0    14260         655           0        490     250000
# ...           ...      ...         ...         ...        ...        ...
# 1455         62.0     7917           0           0        953     175000
# 1456         85.0    13175         790         163        589     210000
# 1457         66.0     9042         275           0        877     266500
# 1458         68.0     9717          49        1029          0     142125
# 1459         75.0     9937         830         290        136     147500
#
# [1460 rows x 6 columns]

# %%
df.dropna(how = "any")
# Out:
#       LotFrontage  LotArea  BsmtFinSF1  BsmtFinSF2  BsmtUnfSF  SalePrice
# 0            65.0     8450         706           0        150     208500
# 1            80.0     9600         978           0        284     181500
# 2            68.0    11250         486           0        434     223500
# 3            60.0     9550         216           0        540     140000
# 4            84.0    14260         655           0        490     250000
# ...           ...      ...         ...         ...        ...        ...
# 1455         62.0     7917           0           0        953     175000
# 1456         85.0    13175         790         163        589     210000
# 1457         66.0     9042         275           0        877     266500
# 1458         68.0     9717          49        1029          0     142125
# 1459         75.0     9937         830         290        136     147500
#
# [1201 rows x 6 columns]

# %%
def lotarea(a):
    return (np.max(a) , np.min(a) , np.mean(a))

# %%
lotarea(df.LotArea)
# Out:
# (215245, 1300, 10516.828082191782)

# %% [markdown]
# #### plotting the correlation between the columns

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# correlation matrix
corr = df.corr()

# %%
sns.heatmap(corr , cmap = "Blues" , linecolor= "Black" ,fmt = "d" )

# %% [markdown]
# #### Plot the distribution of LotArea

# %%
sns.distplot(df.LotArea , bins = 50 , hist = False,vertical= False , )

# %% [markdown]
# ### Pair plot the following columns : 'LotFrontage','BsmtFinSF1','BsmtFinSF2','BsmtUnfSF‘,’SalePrice’

# %%
sns.pairplot(df)

# %% [markdown]
# # Run regression model based on above four columns and check the accuracy

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   LotFrontage  1201 non-null   float64
#  1   LotArea      1460 non-null   int64
#  2   BsmtFinSF1   1460 non-null   int64
#  3   BsmtFinSF2   1460 non-null   int64
#  4   BsmtUnfSF    1460 non-null   int64
#  5   SalePrice    1460 non-null   int64
# dtypes: float64(1), int64(5)
# memory usage: 68.6 KB

# %%
df.LotFrontage.count
# Out:
# <bound method Series.count of 0       65.0
# 1       80.0
# 2       68.0
# 3       60.0
# 4       84.0
#         ...
# 1455    62.0
# 1456    85.0
# 1457    66.0
# 1458    68.0
# 1459    75.0
# Name: LotFrontage, Length: 1460, dtype: float64>

# %%
X = df.iloc[: , 1:-1].values

# %%
y = df.iloc[: , -1].values

# %%
X.shape
# Out:
# (1460, 4)

# %%
y.shape
# Out:
# (1460,)

# %%
from sklearn.model_selection import train_test_split
X_train , X_test , y_train, y_test = train_test_split(X , y , test_size = 0.2 , random_state = 500)

# %%
#X_train.shape
y_train.shape
# Out:
# (1168,)

# %%
print(len(X_train) , len(X_test))
# Out:
# 1168 292

# %%
print(len(y_train) , len(y_test))
# Out:
# 1168 292

# %%
from sklearn.linear_model import LinearRegression
reg = LinearRegression()

# %%
reg.fit(X_train , y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
reg.score(X_test , y_test)
# Out:
# 0.4568251453208985

# %%
df[0:1]
# Out:
#    LotFrontage  LotArea  BsmtFinSF1  BsmtFinSF2  BsmtUnfSF  SalePrice
# 0         65.0     8450         706           0        150     208500

# %%
reg.predict([[8450 , 706 , 0 , 150]])
# Out:
# array([162204.24645659])
